# %%
import pandas as pd
#import matplot

# %%
file = "Resources/Crime_Data_LA_from_2010_to_Present.csv"

crime_df = pd.read_csv(file)
crime_df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
crime_df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
crime_df.shape
# Out:
# (2109752, 28)

# %%
crime_df["Crm Cd Desc"].nunique()
# Out:
# 141

# %%
# crime_counts = crime_df.groupby("Crm Cd Desc")
# count= crime_counts.value_counts
# crime_df['count']=

# %%
crime_df.count()
# Out:
# DR_NO             2109752
# Date Rptd         2109752
# DATE OCC          2109752
# TIME OCC          2109752
# AREA              2109752
# AREA NAME         2109752
# Rpt Dist No       2109752
# Part 1-2          2109752
# Crm Cd            2109752
# Crm Cd Desc       2109752
# Mocodes           1882297
# Vict Age          2109752
# Vict Sex          1913234
# Vict Descent      1913187
# Premis Cd         2109699
# Premis Desc       2109567
# Weapon Used Cd     709393
# Weapon Desc        709392
# Status            2109749
# Status Desc       2109752
# Crm Cd 1          2109742
# Crm Cd 2           138757
# Crm Cd 3             3474
# Crm Cd 4              104
# LOCATION          2109752
# Cross Street       354968
# LAT               2109752
# LON               2109752
# dtype: int64

# %%
crime_2 = crime_df.loc[:,['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME', 
                          'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes', 
                          'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc', 
                          'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'LOCATION', 'Cross Street', 'LAT', 
                          'LON']]
crime_2

crime_df_2=pd.DataFrame(crime_2)
crime_df_2.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Premis Cd  \
# 0                           VIOLATION OF COURT ORDER  ...     501.0
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     101.0
# ...

# %%
crime_df_2.count()
# Out:
# DR_NO             2109752
# Date Rptd         2109752
# DATE OCC          2109752
# TIME OCC          2109752
# AREA              2109752
# AREA NAME         2109752
# Rpt Dist No       2109752
# Part 1-2          2109752
# Crm Cd            2109752
# Crm Cd Desc       2109752
# Mocodes           1882297
# Vict Age          2109752
# Vict Sex          1913234
# Vict Descent      1913187
# Premis Cd         2109699
# Premis Desc       2109567
# Weapon Used Cd     709393
# Weapon Desc        709392
# Status            2109749
# Status Desc       2109752
# LOCATION          2109752
# Cross Street       354968
# LAT               2109752
# LON               2109752
# dtype: int64

# %%
pd.options.display.max_rows = 500

# %%
display(crime_df_2["Crm Cd Desc"].value_counts())
# Out:
# BATTERY - SIMPLE ASSAULT                                    190535
# BURGLARY FROM VEHICLE                                       162098
# VEHICLE - STOLEN                                            159781
# THEFT PLAIN - PETTY ($950 & UNDER)                          149623
# BURGLARY                                                    147465
# THEFT OF IDENTITY                                           126006
# INTIMATE PARTNER - SIMPLE ASSAULT                           114489
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     109390
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT               92666
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)                     90405
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)              88397
# ROBBERY                                                      83844
# THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD     74344
# CRIMINAL THREATS - NO WEAPON DISPLAYED                       56625
# ...

# %%
crime_df.shape
# Out:
# (2109752, 28)
