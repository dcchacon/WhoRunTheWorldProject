# %%
# !pip install us
# Out:
# Requirement already satisfied: us in c:\users\eugen\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: jellyfish==0.5.6 in c:\users\eugen\anaconda3\lib\site-packages (from us) (0.5.6)

# %%
#Dependencies
from census import Census
from config_census import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from us import states
from scipy.stats import linregress
from matplotlib import pyplot as plt
import gmaps.datasets
# Census API Key
c = Census(census_key, year=2017)

# %%
c

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd.head()
# Out:
#           Name  Household Income  Population  Median Age  Per Capita Income  \
# 0  ZCTA5 00601           11757.0     17599.0        38.9             7041.0
# 1  ZCTA5 00602           16190.0     39209.0        40.9             8978.0
# 2  ZCTA5 00603           16645.0     50135.0        40.4            10897.0
# 3  ZCTA5 00606           13387.0      6304.0        42.8             5960.0
# 4  ZCTA5 00610           18741.0     27590.0        41.4             9266.0
#
#    Poverty Count Zipcode
# 0        11282.0   00601
# 1        20428.0   00602
# 2        25176.0   00603
# 3         4092.0   00606
# 4        12553.0   00610

# %%
census_pd.count()
# Out:
# Name                 33120
# Household Income     33120
# Population           33120
# Median Age           33120
# Per Capita Income    32795
# Poverty Count        33120
# Zipcode              33120
# dtype: int64

# %%
census_pd.dropna(how='any')
# Out:
#               Name  Household Income  Population   Median Age  \
# 0      ZCTA5 00601           11757.0     17599.0         38.9
# 1      ZCTA5 00602           16190.0     39209.0         40.9
# 2      ZCTA5 00603           16645.0     50135.0         40.4
# 3      ZCTA5 00606           13387.0      6304.0         42.8
# 4      ZCTA5 00610           18741.0     27590.0         41.4
# ...            ...               ...         ...          ...
# 33115  ZCTA5 99923      -666666666.0         0.0 -666666666.0
# 33116  ZCTA5 99925           48646.0       901.0         45.1
# 33117  ZCTA5 99926           57969.0      1684.0         32.8
# 33118  ZCTA5 99927           17981.0        59.0         49.8
# 33119  ZCTA5 99929           55742.0      2455.0         49.0
#
#        Per Capita Income  Poverty Count Zipcode
# 0                 7041.0        11282.0   00601
# 1                 8978.0        20428.0   00602
# 2                10897.0        25176.0   00603
# 3                 5960.0         4092.0   00606
# 4                 9266.0        12553.0   00610
# ...                  ...            ...     ...
# 33115       -666666666.0            0.0   99923
# 33116            24783.0          210.0   99925
# 33117            22927.0          224.0   99926
# 33118            11959.0           49.0   99927
# 33119            29861.0          276.0   99929
#
# [32795 rows x 7 columns]

# %%
# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * census_pd["Poverty Count"].astype(float) / census_pd["Population"].astype(float)
census_pd.head()
# Out:
#           Name  Household Income  Population  Median Age  Per Capita Income  \
# 0  ZCTA5 00601           11757.0     17599.0        38.9             7041.0
# 1  ZCTA5 00602           16190.0     39209.0        40.9             8978.0
# 2  ZCTA5 00603           16645.0     50135.0        40.4            10897.0
# 3  ZCTA5 00606           13387.0      6304.0        42.8             5960.0
# 4  ZCTA5 00610           18741.0     27590.0        41.4             9266.0
#
#    Poverty Count Zipcode  Poverty Rate
# 0        11282.0   00601     64.105915
# 1        20428.0   00602     52.100283
# 2        25176.0   00603     50.216416
# 3         4092.0   00606     64.911168
# 4        12553.0   00610     45.498369

# %%
# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate"]]

census_pd.head()
# Out:
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601     17599.0        38.9           11757.0             7041.0
# 1   00602     39209.0        40.9           16190.0             8978.0
# 2   00603     50135.0        40.4           16645.0            10897.0
# 3   00606      6304.0        42.8           13387.0             5960.0
# 4   00610     27590.0        41.4           18741.0             9266.0
#
#    Poverty Count  Poverty Rate
# 0        11282.0     64.105915
# 1        20428.0     52.100283
# 2        25176.0     50.216416
# 3         4092.0     64.911168
# 4        12553.0     45.498369

# %%
# Visualize
print(len(census_pd))
# Out:
# 33120

# %%
zip_codes=[90001, 90002, 90005, 90006, 90003, 90004, 90007, 90008, 90010, 90013, 90014, 90017, 90021, 90009, 90011, 90012, 90015, 90016,
90018, 90019, 90020, 90022, 90025, 90027, 90031, 90032, 90023, 90024, 90026, 90028, 90029, 90030, 90033, 90034, 90037, 90039, 90042, 90043, 90045, 90035, 90036, 90038, 90040, 90041, 90044, 90046, 90048, 90052, 90053, 90054, 90057, 90058, 90047, 90049, 90050, 90051, 90055, 90056, 90059, 90062, 90063, 90064, 90065, 90066, 90070, 90060, 90061, 90067, 90068, 90071, 90072, 90074, 90078, 90079, 90084, 90086, 90087, 90095, 90096, 90073, 90075, 90076, 90077, 90080, 90081, 90082, 90083, 90088,
90089, 90091, 90093, 90099, 90189, 90101, 90103]

zip_codes_df=pd.DataFrame({"Zipcode": zip_codes})
zip_codes_df.head()
# Out:
#    Zipcode
# 0    90001
# 1    90002
# 2    90005
# 3    90006
# 4    90003

# %%
zip_codes_df.count
# Out:
# <bound method DataFrame.count of     Zipcode
# 0     90001
# 1     90002
# 2     90005
# 3     90006
# 4     90003
# ..      ...
# 90    90093
# 91    90099
# 92    90189
# 93    90101
# 94    90103
#
# [95 rows x 1 columns]>

# %%
census_pd.dtypes
# Out:
# Zipcode               object
# Population           float64
# Median Age           float64
# Household Income     float64
# Per Capita Income    float64
# Poverty Count        float64
# Poverty Rate         float64
# dtype: object

# %%
census_pd['Zipcode'].astype(str)
# Out:
# 0        00601
# 1        00602
# 2        00603
# 3        00606
# 4        00610
#          ...
# 33115    99923
# 33116    99925
# 33117    99926
# 33118    99927
# 33119    99929
# Name: Zipcode, Length: 33120, dtype: object

# %%
zip_codes_df.dtypes
# Out:
# Zipcode    int64
# dtype: object

# %%
zip_codes_df['Zipcode']=zip_codes_df['Zipcode'].astype(str)

# %%
zip_codes_df.dtypes
# Out:
# Zipcode    object
# dtype: object

# %%
la_df=pd.merge(zip_codes_df, census_pd, on='Zipcode', how='inner')
la_df.head()
# Out:
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   90001     58738.0        28.7           35660.0            11882.0
# 1   90002     52856.0        27.7           34000.0            11807.0
# 2   90005     39562.0        35.4           32461.0            21566.0
# 3   90006     62329.0        33.2           33790.0            15314.0
# 4   90003     70490.0        28.2           34397.0            11305.0
#
#    Poverty Count  Poverty Rate
# 0        18654.0     31.757976
# 1        17795.0     33.666944
# 2        11300.0     28.562762
# 3        17720.0     28.429784
# 4        23212.0     32.929494

# %%
la_df.count()
# Out:
# Zipcode              65
# Population           65
# Median Age           65
# Household Income     65
# Per Capita Income    65
# Poverty Count        65
# Poverty Rate         62
# dtype: int64

# %%
la_df=la_df.dropna()
la_df.count()
# Out:
# Zipcode              62
# Population           62
# Median Age           62
# Household Income     62
# Per Capita Income    62
# Poverty Count        62
# Poverty Rate         62
# dtype: int64

# %%
gmaps.configure(api_key=gkey)

# %%
pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in c:\users\eugen\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: numpy in c:\users\eugen\anaconda3\lib\site-packages (from pgeocode) (1.16.5)
# Requirement already satisfied: pandas in c:\users\eugen\anaconda3\lib\site-packages (from pgeocode) (0.25.1)
# Requirement already satisfied: requests in c:\users\eugen\anaconda3\lib\site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\eugen\anaconda3\lib\site-packages (from pandas->pgeocode) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\eugen\anaconda3\lib\site-packages (from pandas->pgeocode) (2.8.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\eugen\anaconda3\lib\site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\eugen\anaconda3\lib\site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eugen\anaconda3\lib\site-packages (from requests->pgeocode) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\eugen\anaconda3\lib\site-packages (from requests->pgeocode) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\eugen\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pgeocode

# %%
lat_lon = []

nomi = pgeocode.Nominatim('US')

for code in zip_codes:

    geo_metrics = nomi.query_postal_code(code)
    lat_lon.append(geo_metrics.to_dict())
    
lat_lon_df = pd.DataFrame(lat_lon)

lat_lon_df = lat_lon_df.rename(columns={"postal_code":"Zipcode",
                                       "latitude": "Latitude",
                                       "longitude": "Longitude"})
lat_lon_df = lat_lon_df[["Zipcode", "Latitude", "Longitude"]]
lat_lon_df = lat_lon_df.dropna()
lat_lon_df
# Out:
#    Zipcode  Latitude  Longitude
# 0    90001   33.9731  -118.2479
# 1    90002   33.9497  -118.2462
# 2    90005   34.0585  -118.3012
# 3    90006   34.0493  -118.2917
# 4    90003   33.9653  -118.2727
# ..     ...       ...        ...
# 88   90089   33.7866  -118.2987
# 89   90091   34.0522  -118.2437
# 90   90093   34.0522  -118.2437
# 91   90099   34.0522  -118.2437
# 92   90189   34.0515  -118.2559
#
# [93 rows x 3 columns]

# %%
la_df=pd.merge(la_df, lat_lon_df, on='Zipcode', how='inner')
la_df.head(62)
# Out:
#    Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0    90001     58738.0        28.7           35660.0            11882.0
# 1    90002     52856.0        27.7           34000.0            11807.0
# 2    90005     39562.0        35.4           32461.0            21566.0
# 3    90006     62329.0        33.2           33790.0            15314.0
# 4    90003     70490.0        28.2           34397.0            11305.0
# ..     ...         ...         ...               ...                ...
# 57   90067      2235.0        65.4          123889.0           148638.0
# 58   90068     21726.0        40.5           82718.0            81674.0
# 59   90073       944.0        55.9      -666666666.0            11695.0
# 60   90077      8936.0        49.2          184722.0           110727.0
# 61   90089      3846.0        19.1      -666666666.0             6764.0
#
#     Poverty Count  Poverty Rate  Latitude  Longitude
# 0         18654.0     31.757976   33.9731  -118.2479
# 1         17795.0     33.666944   33.9497  -118.2462
# 2         11300.0     28.562762   34.0585  -118.3012
# 3         17720.0     28.429784   34.0493  -118.2917
# 4         23212.0     32.929494   33.9653  -118.2727
# ..            ...           ...       ...        ...
# 57          108.0      4.832215   34.0551  -118.4095
# 58         2238.0     10.301022   34.1156  -118.3305
# 59          461.0     48.834746   33.7866  -118.2987
# 60          372.0      4.162936   34.1112  -118.4502
# 61           15.0      0.390016   33.7866  -118.2987
#
# [62 rows x 9 columns]

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = la_df[["Latitude", "Longitude"]].astype(float)

# %%
# Convert Poverty Rate to float and store
poverty_rate = la_df["Poverty Rate"].astype(float)

# %%
weights = la_df["Poverty Rate"].astype(float)
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=poverty_rate, dissipating=True, opacity=0.6))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
la_df.to_csv("Output/2017.csv", index=False, header=True)
