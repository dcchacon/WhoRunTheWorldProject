# %%
import pandas as pd

# %%
#import csv_file
csv_file='Resources/Crime_Data_LA_from_2010_to_Present.csv'
# Out:
# 'Resources/Crime_Data_LA_from_2010_to_Present.csv'

# %%
#convert csv to dataframe
crime_data_df=pd.read_csv(csv_file)
crime_data_df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
pd.options.display.max_rows = 500

# %%
assignee_group=crime_data_df.groupby('Crm Cd Desc')
total_count=assignee_group['Crm Cd Desc'].count()
#total number of crimes
display(df = pd.DataFrame(total_count))
df.head()
# Out:
#                                                 Crm Cd Desc
# Crm Cd Desc
# ABORTION/ILLEGAL                                          7
# ARSON                                                  3531
# ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER           1604
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        92666
# ATTEMPTED ROBBERY                                     11989

# %%
crime_data_df.shape
# Out:
# (2109752, 28)

# %%
#crime_data_df[crime_data_df['Crm Cd Desc'] == 'ABORTION/ILLEGAL'].shape
# Out:
# (7, 28)

# %%
pd.DataFrame(crime_data_df['Crm Cd Desc'].value_counts()).reset_index()
# Out:
#                                                  index  Crm Cd Desc
# 0                             BATTERY - SIMPLE ASSAULT       190535
# 1                                BURGLARY FROM VEHICLE       162098
# 2                                     VEHICLE - STOLEN       159781
# 3                   THEFT PLAIN - PETTY ($950 & UNDER)       149623
# 4                                             BURGLARY       147465
# 5                                    THEFT OF IDENTITY       126006
# 6                    INTIMATE PARTNER - SIMPLE ASSAULT       114489
# 7    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...       109390
# 8       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        92666
# 9             VANDALISM - MISDEAMEANOR ($399 OR UNDER)        90405
# 10     THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        88397
# 11                                             ROBBERY        83844
# 12   THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        74344
# ...
